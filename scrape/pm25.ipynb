# %%
import pandas as pd

# %%
url='https://sta.ci.taiwan.gov.tw/STA_AirQuality_v2/v1.0/Datastreams?$expand=Thing,Observations($orderby=phenomenonTime%20desc;$top=1)&$filter=name%20eq%20%27PM2.5%27%20and%20Thing/properties/authority%20eq%20%27%E8%A1%8C%E6%94%BF%E9%99%A2%E7%92%B0%E5%A2%83%E4%BF%9D%E8%AD%B7%E7%BD%B2%27%20and%20substringof(%27%E7%A9%BA%E6%B0%A3%E5%93%81%E8%B3%AA%E6%B8%AC%E7%AB%99%27,Thing/name)&$count=true'

# %%
datas=pd.read_json(url)['value']
datas
# Out:
# 0     {'description': '細懸浮微粒 PM2.5', '@iot.id': 11, ...
# 1     {'description': '細懸浮微粒 PM2.5', '@iot.id': 29, ...
# 2     {'description': '細懸浮微粒 PM2.5', '@iot.id': 47, ...
# 3     {'description': '細懸浮微粒 PM2.5', '@iot.id': 65, ...
# 4     {'description': '細懸浮微粒 PM2.5', '@iot.id': 83, ...
#                             ...
# 72    {'description': '細懸浮微粒 PM2.5', '@iot.id': 1307...
# 73    {'description': '細懸浮微粒 PM2.5', '@iot.id': 1325...
# 74    {'description': '細懸浮微粒 PM2.5', '@iot.id': 1343...
# 75    {'description': '細懸浮微粒 PM2.5', '@iot.id': 1361...
# 76    {'description': '細懸浮微粒 PM2.5', '@iot.id': 1379...
# Name: value, Length: 77, dtype: object

# %%
len(datas)
# Out:
# 77

# %%
county,stationName=datas[0]['Thing']['properties']['city'],\
    datas[0]['Thing']['properties']['stationName']

county,stationName
# Out:
# ('基隆市', '基隆')

# %%
result,resultTime=datas[0]['Observations'][0]['result'],datas[0]['Observations'][0]['resultTime']
result,resultTime
# Out:
# (12, '2022-07-09T05:00:00.000Z')

# %% [markdown]
# ### 取得縣市跟站點等資料

# %%
values=[]
for data in datas:
    try:
        city,stationName=data['Thing']['properties']['city'],\
        data['Thing']['properties']['stationName']

        result,resultTime=data['Observations'][0]['result'],data['Observations'][0]['resultTime']
        resultTime=pd.to_datetime(resultTime).strftime('%Y-%m-%d %H:%M:%S')
        print(city,stationName,result,resultTime)
        values.append([city,stationName,result,resultTime])
    except Exception as e:
        print(e)
# Out:
# 基隆市 基隆 12 2022-07-09 05:00:00
# 新北市 汐止 17 2022-07-09 05:00:00
# 新北市 萬里 11 2022-07-09 05:00:00
# 新北市 新店 9 2022-07-09 05:00:00
# 新北市 土城 14 2022-07-09 05:00:00
# 新北市 板橋 12 2022-07-09 05:00:00
# 新北市 新莊 17 2022-07-09 05:00:00
# 新北市 菜寮 18 2022-07-09 05:00:00
# 新北市 林口 15 2022-07-09 05:00:00
# 新北市 淡水 7 2022-07-09 05:00:00
# 臺北市 士林 13 2022-07-09 05:00:00
# 臺北市 中山 15 2022-07-09 05:00:00
# 臺北市 萬華 17 2022-07-09 05:00:00
# 臺北市 古亭 15 2022-07-09 05:00:00
# 臺北市 松山 17 2022-07-09 05:00:00
# 臺北市 大同 16 2022-07-09 05:00:00
# 桃園市 桃園 13 2022-07-09 05:00:00
# 桃園市 大園 7 2022-07-09 05:00:00
# 桃園市 觀音 7 2022-07-09 05:00:00
# 桃園市 平鎮 11 2022-07-09 05:00:00
# 桃園市 龍潭 13 2022-07-09 05:00:00
# 新竹縣 湖口 9 2022-07-09 05:00:00
# 新竹縣 竹東 14 2022-07-09 05:00:00
# 新竹市 新竹 7 2022-07-09 05:00:00
# 苗栗縣 頭份 4 2022-07-09 05:00:00
# 苗栗縣 苗栗 8 2022-07-09 05:00:00
# 苗栗縣 三義 16 2022-07-09 05:00:00
# 臺中市 豐原 21 2022-07-09 05:00:00
#  ['臺北市', '中山', 15, '2022-07-09 05:00:00'],
#  ['臺北市', '萬華', 17, '2022-07-09 05:00:00'],
#  ['臺北市', '古亭', 15, '2022-07-09 05:00:00'],
#  ['臺北市', '松山', 17, '2022-07-09 05:00:00'],
#  ['臺北市', '大同', 16, '2022-07-09 05:00:00'],
#  ['桃園市', '桃園', 13, '2022-07-09 05:00:00'],
#  ['桃園市', '大園', 7, '2022-07-09 05:00:00'],
#  ['桃園市', '觀音', 7, '2022-07-09 05:00:00'],
#  ['桃園市', '平鎮', 11, '2022-07-09 05:00:00'],
#  ['桃園市', '龍潭', 13, '2022-07-09 05:00:00'],
#  ['新竹縣', '湖口', 9, '2022-07-09 05:00:00'],
#  ['新竹縣', '竹東', 14, '2022-07-09 05:00:00'],
#  ['新竹市', '新竹', 7, '2022-07-09 05:00:00'],
#  ['苗栗縣', '頭份', 4, '2022-07-09 05:00:00'],
#  ['苗栗縣', '苗栗', 8, '2022-07-09 05:00:00'],
#  ['苗栗縣', '三義', 16, '2022-07-09 05:00:00'],
#  ['臺中市', '豐原', 21, '2022-07-09 05:00:00'],
#  ['臺中市', '沙鹿', 11, '2022-07-09 05:00:00'],
#  ['臺中市', '大里', 14, '2022-07-09 05:00:00'],
#  ['臺中市', '忠明', 15, '2022-07-09 05:00:00'],
#  ['臺中市', '西屯', 12, '2022-07-09 05:00:00'],
#  ['彰化縣', '彰化', 10, '2022-07-09 05:00:00'],
#  ['彰化縣', '線西', 6, '2022-07-09 05:00:00'],
#  ['彰化縣', '二林', 22, '2022-07-09 05:00:00'],
#  ['南投縣', '南投', 11, '2022-07-09 05:00:00'],
#  ['雲林縣', '斗六', 16, '2022-07-09 05:00:00'],
#  ['雲林縣', '崙背', 19, '2022-07-09 05:00:00'],
#  ['嘉義縣', '新港', 27, '2022-07-09 05:00:00'],
#  ['嘉義縣', '朴子', 7, '2022-07-09 05:00:00'],
#  ['雲林縣', '臺西', 10, '2022-07-09 05:00:00'],
#  ['嘉義市', '嘉義', 16, '2022-07-09 05:00:00'],
#  ['臺南市', '新營', 13, '2022-07-09 05:00:00'],
#  ['臺南市', '善化', 9, '2022-07-09 05:00:00'],
#  ['臺南市', '安南', 13, '2022-07-09 05:00:00'],
#  ['臺南市', '臺南', 16, '2022-07-09 05:00:00'],
#  ['高雄市', '美濃', 2, '2022-07-09 05:00:00'],
#  ['高雄市', '橋頭', 6, '2022-07-09 05:00:00'],
#  ['高雄市', '仁武', 11, '2022-07-09 05:00:00'],
#  ['高雄市', '鳳山', 7, '2022-07-09 05:00:00'],
#  ['高雄市', '大寮', 5, '2022-07-09 05:00:00'],
#  ['高雄市', '林園', 0, '2022-07-09 05:00:00'],
#  ['高雄市', '楠梓', 8, '2022-07-09 05:00:00'],
#  ['高雄市', '左營', 7, '2022-07-09 05:00:00'],
#  ['高雄市', '前金', 2, '2022-07-09 05:00:00'],
#  ['高雄市', '前鎮', 1, '2022-07-09 05:00:00'],
#  ['高雄市', '小港', 4, '2022-07-09 05:00:00'],
#  ['屏東縣', '屏東', 11, '2022-07-09 05:00:00'],
#  ['屏東縣', '潮州', 6, '2022-07-09 05:00:00'],
#  ['屏東縣', '恆春', 0, '2022-07-09 05:00:00'],
#  ['臺東縣', '臺東', 5, '2022-07-09 05:00:00'],
#  ['花蓮縣', '花蓮', 3, '2022-07-09 05:00:00'],
#  ['臺北市', '陽明', 17, '2022-07-09 05:00:00'],
#  ['宜蘭縣', '宜蘭', 6, '2022-07-09 05:00:00'],
#  ['宜蘭縣', '冬山', 6, '2022-07-09 05:00:00'],
#  ['新北市', '三重', 17, '2022-07-09 05:00:00'],
#  ['桃園市', '中壢', 13, '2022-07-09 05:00:00'],
#  ['南投縣', '竹山', 13, '2022-07-09 05:00:00'],
#  ['新北市', '永和', 15, '2022-07-09 05:00:00'],
#  ['高雄市', '復興', 1, '2022-07-09 05:00:00'],
#  ['南投縣', '埔里', 2, '2022-07-09 05:00:00'],
#  ['新北市', '富貴角', 3, '2022-07-09 05:00:00'],
#  ['臺東縣', '關山', 0, '2022-07-09 05:00:00'],
#  ['金門縣', '金門', 1, '2022-07-09 05:00:00'],
#  ['連江縣', '馬祖', 7, '2022-07-09 05:00:00'],
#  ['澎湖縣', '馬公', 6, '2022-07-09 05:00:00'],
#  ['雲林縣', '麥寮', 6, '2022-07-09 05:00:00']]

# %%
df=pd.DataFrame(values,columns=['city','stationName','result','resultTime'])
df
# Out:
#    city stationName  result           resultTime
# 0   基隆市          基隆      12  2022-07-09 05:00:00
# 1   新北市          汐止      17  2022-07-09 05:00:00
# 2   新北市          萬里      11  2022-07-09 05:00:00
# 3   新北市          新店       9  2022-07-09 05:00:00
# 4   新北市          土城      14  2022-07-09 05:00:00
# ..  ...         ...     ...                  ...
# 72  臺東縣          關山       0  2022-07-09 05:00:00
# 73  金門縣          金門       1  2022-07-09 05:00:00
# 74  連江縣          馬祖       7  2022-07-09 05:00:00
# 75  澎湖縣          馬公       6  2022-07-09 05:00:00
# 76  雲林縣          麥寮       6  2022-07-09 05:00:00
#
# [77 rows x 4 columns]

# %% [markdown]
# ### 取得六都平均值

# %%
set(df['city'])
# Out:
# {'南投縣',
#  '嘉義市',
#  '嘉義縣',
#  '基隆市',
#  '宜蘭縣',
#  '屏東縣',
#  '彰化縣',
#  '新北市',
#  '新竹市',
#  '新竹縣',
#  '桃園市',
#  '澎湖縣',
#  '臺中市',
#  '臺北市',
#  '臺南市',
#  '臺東縣',
#  '花蓮縣',
#  '苗栗縣',
#  '連江縣',
#  '金門縣',
#  '雲林縣',
#  '高雄市'}

# %%
six_city=['臺北市','新北市','桃園市','臺中市','臺南市','高雄市']
six_city
# Out:
# ['臺北市', '新北市', '桃園市', '臺中市', '臺南市', '高雄市']

# %%
round(df.groupby('city').get_group(six_city[0])['result'].mean(),2)
# Out:
# 15.71

# %%
for city in six_city:
    print(city,round(df.groupby('city').get_group(city)['result'].mean(),2))
# Out:
# 臺北市 15.71
# 新北市 12.92
# 桃園市 10.67
# 臺中市 14.6
# 臺南市 12.75
# 高雄市 4.5

# %% [markdown]
# ### 取得單一縣市的站點跟PM2.5

# %%
citys=set(df['city'])

citys
# Out:
# {'南投縣',
#  '嘉義市',
#  '嘉義縣',
#  '基隆市',
#  '宜蘭縣',
#  '屏東縣',
#  '彰化縣',
#  '新北市',
#  '新竹市',
#  '新竹縣',
#  '桃園市',
#  '澎湖縣',
#  '臺中市',
#  '臺北市',
#  '臺南市',
#  '臺東縣',
#  '花蓮縣',
#  '苗栗縣',
#  '連江縣',
#  '金門縣',
#  '雲林縣',
#  '高雄市'}
